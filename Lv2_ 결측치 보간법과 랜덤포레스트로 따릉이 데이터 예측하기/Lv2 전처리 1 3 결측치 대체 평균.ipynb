# %% [markdown]
# # [↩️ 리스트로 돌아가기](https://dacon.io/competitions/open/235698/overview/description)

# %% [markdown]
# # 셀을 실행할 때 팝업이 뜨면 `무시하고 계속하기` 를 눌러주세요

# %% [markdown]
# ## 데이터 다운로드
# ---
# 아래 셀을 실행시켜 데이터를 colab에 불러옵니다.
# 셀 실행은 <br>Windows: `Ctrl` + `Enter`<br>
# Mac: `Shift` + `Enter` <br>
# 를 이용해 실행 시킬 수 있습니다.

# %%
# 데이터 다운로드 링크로 데이터를 코랩에 불러옵니다.

# !wget 'https://bit.ly/3gLj0Q6'

import zipfile
with zipfile.ZipFile('3gLj0Q6', 'r') as existing_zip:
    existing_zip.extractall('data')
# Out:
# --2022-10-04 08:12:58--  https://bit.ly/3gLj0Q6
# Resolving bit.ly (bit.ly)... 67.199.248.10, 67.199.248.11
# Connecting to bit.ly (bit.ly)|67.199.248.10|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://drive.google.com/uc?export=download&id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E [following]
# --2022-10-04 08:12:58--  https://drive.google.com/uc?export=download&id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E
# Resolving drive.google.com (drive.google.com)... 172.217.219.139, 172.217.219.102, 172.217.219.100, ...
# Connecting to drive.google.com (drive.google.com)|172.217.219.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/59fcnsvclkk33sn7tvi69cng32400k99/1664871150000/17946651057176172524/*/1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E?e=download&uuid=b3abeaab-b85f-487b-9e3a-c7a18d26e8e3 [following]
# Warning: wildcards not supported in HTTP.
# --2022-10-04 08:12:58--  https://doc-0c-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/59fcnsvclkk33sn7tvi69cng32400k99/1664871150000/17946651057176172524/*/1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E?e=download&uuid=b3abeaab-b85f-487b-9e3a-c7a18d26e8e3
# Resolving doc-0c-10-docs.googleusercontent.com (doc-0c-10-docs.googleusercontent.com)... 142.250.152.132, 2607:f8b0:4001:c56::84
# Connecting to doc-0c-10-docs.googleusercontent.com (doc-0c-10-docs.googleusercontent.com)|142.250.152.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39208 (38K) [application/zip]
# Saving to: ‘3gLj0Q6’
#
# 3gLj0Q6             100%[===================>]  38.29K  --.-KB/s    in 0.001s
#
# 2022-10-04 08:12:59 (66.8 MB/s) - ‘3gLj0Q6’ saved [39208/39208]

# %% [markdown]
# ## 데이터 불러오기
# ---

# %%
import pandas as pd

train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %% [markdown]
# ## 👋 실습
# ---
# 결측치가 있는 피쳐를 살펴본 후, 각 평균치로 대체해주세요

# %% [markdown]
# ## 결측치가 있는 피쳐 살펴보기
# ---

# %%
print("train=============\n",train.isnull().sum())
print("test=============\n",test.isnull().sum())
# Out:
# train=============
#  id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64
# test=============
#  id                         0
# hour                       0
# hour_bef_temperature       1
# hour_bef_precipitation     1
# hour_bef_windspeed         1
# hour_bef_humidity          1
# hour_bef_visibility        1
# hour_bef_ozone            35
# hour_bef_pm10             37
# hour_bef_pm2.5            36
# dtype: int64

# %% [markdown]
# ## 결측치 평균값으로 대체하기
# ---
# fillna() 를 이용해 결측치를 각 피쳐의 평균값으로 대체하는 코드를 아래에 작성하세요.

# %%
train.mean()
# Out:
# id                        1105.914325
# hour                        11.493489
# hour_bef_temperature        16.717433
# hour_bef_precipitation       0.031572
# hour_bef_windspeed           2.479034
# hour_bef_humidity           52.231297
# hour_bef_visibility       1405.216884
# hour_bef_ozone               0.039149
# hour_bef_pm10               57.168736
# hour_bef_pm2.5              30.327124
# count                      108.563400
# dtype: float64

# %%
train[train['hour_bef_temperature'].isnull()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 934   1420     0                   NaN                     NaN
# 1035  1553    18                   NaN                     NaN
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 934                  NaN                NaN                  NaN
# 1035                 NaN                NaN                  NaN
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 934              NaN            NaN             NaN   39.0
# 1035             NaN            NaN             NaN    1.0

# %%
train.fillna({'hour_bef_temperature':int(train['hour_bef_temperature'].mean())}, inplace=True)

# %%
train['hour_bef_temperature']
# Out:
# 0       16.3
# 1       20.1
# 2       13.9
# 3        8.1
# 4       29.5
#         ...
# 1454    16.8
# 1455    10.8
# 1456    18.3
# 1457    20.7
# 1458    21.1
# Name: hour_bef_temperature, Length: 1459, dtype: float64

# %% [markdown]
# ### numpy.where문 사용
# numpy.where(조건문, TRUE값, FALSE값)
#  출처 : https://rfriend.tistory.com/262

# %%
import numpy as np

# %%
train.where(pd.notnull(train), train.mean(), axis='columns', inplace=True)

# %% [markdown]
# ## 결과확인
# ---

# %%
print(train.isnull().sum())
# Out:
# id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            0
# count                     0
# dtype: int64

# %% [markdown]
# ## 정답

# %%
import pandas as pd

# 정답 코드
train = pd.read_csv('data/train.csv') 
test = pd.read_csv('data/test.csv')

# %%
print(train.isnull().sum())

# %%
train.fillna({'hour_bef_temperature':int(train['hour_bef_temperature'].mean())}, inplace=True)
train.fillna({'hour_bef_precipitation':int(train['hour_bef_precipitation'].mean())}, inplace=True)
train.fillna({'hour_bef_windspeed':int(train['hour_bef_windspeed'].mean())}, inplace=True)
train.fillna({'hour_bef_humidity':int(train['hour_bef_humidity'].mean())}, inplace=True)
train.fillna({'hour_bef_visibility':int(train['hour_bef_visibility'].mean())}, inplace=True)
train.fillna({'hour_bef_ozone':int(train['hour_bef_ozone'].mean())}, inplace=True)
train.fillna({'hour_bef_pm10':int(train['hour_bef_pm10'].mean())}, inplace=True)
train.fillna({'hour_bef_pm2.5':int(train['hour_bef_pm2.5'].mean())}, inplace=True)

# %%
print(train.isnull().sum())

# %% [markdown]
# # [↩️ 리스트로 돌아가기](https://dacon.io/competitions/open/235698/overview/description)
